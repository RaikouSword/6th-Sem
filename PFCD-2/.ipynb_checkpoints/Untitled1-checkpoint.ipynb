# %%
import sys
# !{sys.executable} -m pip install regex nltk textblob
# Out:
# Requirement already satisfied: regex in /home/iteradmin/.conda/envs/jupyter_fix/lib/python3.9/site-packages (2026.1.15)
# Requirement already satisfied: nltk in /home/iteradmin/.local/lib/python3.9/site-packages (3.9.2)
# Requirement already satisfied: textblob in /home/iteradmin/.local/lib/python3.9/site-packages (0.19.0)
# Requirement already satisfied: click in /home/iteradmin/.conda/envs/jupyter_fix/lib/python3.9/site-packages (from nltk) (8.1.8)
# Requirement already satisfied: joblib in /home/iteradmin/.conda/envs/jupyter_fix/lib/python3.9/site-packages (from nltk) (1.5.2)
# Requirement already satisfied: tqdm in /home/iteradmin/.conda/envs/jupyter_fix/lib/python3.9/site-packages (from nltk) (4.67.3)

# %%
from textblob import TextBlob
text = 'Today is a beautiful day.'
blob = TextBlob(text)
blob
# Out:
# TextBlob("Today is a beautiful day.")

# %%
blob.sentences
# Out:
# [Sentence("Today is a beautiful day.")]

# %%
blob.words
# Out:
# WordList(['Today', 'is', 'a', 'beautiful', 'day'])

# %%
blob.tags
# Out:
# [('Today', 'NN'),
#  ('is', 'VBZ'),
#  ('a', 'DT'),
#  ('beautiful', 'JJ'),
#  ('day', 'NN')]

# %%
blob.noun_phrases
# Out:
# WordList(['beautiful day'])

# %%
blob.sentiment
# Out:
# Sentiment(polarity=0.85, subjectivity=1.0)

# %%
# %precision 3
# Out:
# '%.3f'

# %%
blob.sentiment.polarity
# Out:
# 0.850

# %%
blob.sentiment.subjectivity
# Out:
# 1.000

# %%
from textblob.sentiments import NaiveBayesAnalyzer
blob = TextBlob(text,analyzer=NaiveBayesAnalyzer())
blob
# Out:
# TextBlob("Today is a beautiful day.")

# %%
blob.sentiment
# Out:
# Sentiment(classification='pos', p_pos=0.8117563121751951, p_neg=0.18824368782480477)

# %%
from textblob import Word
index = Word("index")
index.pluralize()
# Out:
# 'indices'

# %%
cacti = Word('cacti')
cacti.singularize()
# Out:
# 'cactus'

# %%
animals = TextBlob("dog cat fish bird").words
animals.pluralize()
# Out:
# WordList(['dogs', 'cats', 'fish', 'birds'])

# %%
from pathlib import Path 
blob = TextBlob(Path("RomeoAndJuliet.txt").read_text())
# text = file_path.read_text(encoding='utf-8')
# blob = TextBlob(text)
# j = blob.word_counts['juliet']
# print(j)

# %%
word = Word("strawberries")
print(word.stem())
print(word.lemmatize())
# Out:
# strawberri
# strawberry

# %%
blob.word_counts['juliet']
# Out:
# 194

# %%
blob.word_counts['romeo']
# Out:
# 319

# %%
blob.word_counts['thou']
# Out:
# 278

# %%
from nltk.corpus import stopwords
stops = stopwords.words('english')
blob = TextBlob('Today is a beautiful day')
[word for word in blob.words if word not in stops]
# Out:
# ['Today', 'beautiful', 'day']

# %%
text = 'Today is a beautiful day. Tomorrow looks like bad weather'
blob = TextBlob(text)
blob.ngrams(10)
# Out:
# [WordList(['Today', 'is', 'a', 'beautiful', 'day', 'Tomorrow', 'looks', 'like', 'bad', 'weather'])]

# %%
stop_words= stopwords.words('english')
items = blob.word_counts.items()
items = [item for item in items if item[0] not in stop_words]
from operator import itemgetter
sorted_items = sorted(items, key= lambda x: x[1], reverse=True)
top20 = sorted_items[1:21]
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
df = pd.DataFrame(top20, columns=['word','count'])
colors = mpl.rcParams['axes.prop_cycle'].by_key()['color']
axes = df.plot.bar(x='word',y='count',legend=False,color=colors)
plt.gcf().tight_layout()

# %%
# !pip install WordCloud
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: WordCloud in /home/iteradmin/.local/lib/python3.9/site-packages (1.9.6)
# Requirement already satisfied: numpy>=1.19.3 in /opt/anaconda3/lib/python3.9/site-packages (from WordCloud) (1.24.3)
# Requirement already satisfied: pillow in /opt/anaconda3/lib/python3.9/site-packages (from WordCloud) (9.4.0)
# Requirement already satisfied: matplotlib in /opt/anaconda3/lib/python3.9/site-packages (from WordCloud) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/lib/python3.9/site-packages (from matplotlib->WordCloud) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/lib/python3.9/site-packages (from matplotlib->WordCloud) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/lib/python3.9/site-packages (from matplotlib->WordCloud) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/anaconda3/lib/python3.9/site-packages (from matplotlib->WordCloud) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/lib/python3.9/site-packages (from matplotlib->WordCloud) (23.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/anaconda3/lib/python3.9/site-packages (from matplotlib->WordCloud) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/anaconda3/lib/python3.9/site-packages (from matplotlib->WordCloud) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in /opt/anaconda3/lib/python3.9/site-packages (from matplotlib->WordCloud) (5.2.0)
# Requirement already satisfied: zipp>=3.1.0 in /opt/anaconda3/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib->WordCloud) (3.11.0)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib->WordCloud) (1.16.0)

# %%
import sys
# !{sys.executable} -m pip install imageio
# Out:
# Collecting imageio
#   Downloading imageio-2.37.2-py3-none-any.whl.metadata (9.7 kB)
# Requirement already satisfied: numpy in /home/iteradmin/.conda/envs/jupyter_fix/lib/python3.9/site-packages (from imageio) (1.26.4)
# Requirement already satisfied: pillow>=8.3.2 in /home/iteradmin/.conda/envs/jupyter_fix/lib/python3.9/site-packages (from imageio) (11.3.0)
# Downloading imageio-2.37.2-py3-none-any.whl (317 kB)
# Installing collected packages: imageio
# Successfully installed imageio-2.37.2

# %%
text = TextBlob(Path('RomeoAndJuliet.txt').read_text())
text = text.raw
import imageio.v2 as imageio
mask_image = imageio.imread('heart.png')
from wordcloud import WordCloud
wordcloud = WordCloud(colormap='prism', mask = mask_image, background_color='white')
wordcloud = wordcloud.generate(text)
wordcloud = wordcloud.to_file('mask_heart.png')
get_ipython().run_line_magic('matplotlib','')
import matplotlib.pyplot as mat
mat.figure(figsize=(10,10))
mat.imshow(wordcloud)
# Out:
# Using matplotlib backend: <object object at 0x71c3e4a48ac0>
# Warning: Ignoring XDG_SESSION_TYPE=wayland on Gnome. Use QT_QPA_PLATFORM=wayland to run on Wayland anyway.
