# %%
import sys
# !{sys.executable} -m pip install regex nltk textblob
# Out:
# Collecting regex
#   Downloading regex-2026.1.15-cp39-cp39-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (40 kB)
# Requirement already satisfied: nltk in /home/iteradmin/.local/lib/python3.9/site-packages (3.9.2)
# Requirement already satisfied: textblob in /home/iteradmin/.local/lib/python3.9/site-packages (0.19.0)
# Collecting click (from nltk)
#   Downloading click-8.1.8-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: joblib in /home/iteradmin/.conda/envs/jupyter_fix/lib/python3.9/site-packages (from nltk) (1.5.2)
# Collecting tqdm (from nltk)
#   Downloading tqdm-4.67.3-py3-none-any.whl.metadata (57 kB)
# Downloading regex-2026.1.15-cp39-cp39-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (791 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 791.3/791.3 kB 16.0 MB/s  0:00:00
# Downloading click-8.1.8-py3-none-any.whl (98 kB)
# Downloading tqdm-4.67.3-py3-none-any.whl (78 kB)
# Installing collected packages: tqdm, regex, click
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3/3 [click]32m2/3 [click]
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pyppeteer 2.0.0 requires appdirs<2.0.0,>=1.4.3, which is not installed.
# pyppeteer 2.0.0 requires urllib3<2.0.0,>=1.25.8, but you have urllib3 2.5.0 which is incompatible.
# Successfully installed click-8.1.8 regex-2026.1.15 tqdm-4.67.3

# %%
from textblob import TextBlob
text = 'Today is a beautiful day.'
blob = TextBlob(text)
blob
# Out:
# TextBlob("Today is a beautiful day.")

# %%
blob.sentences
# Out:
# [Sentence("Today is a beautiful day.")]

# %%
blob.words
# Out:
# WordList(['Today', 'is', 'a', 'beautiful', 'day'])

# %%
blob.tags
# Out:
# [('Today', 'NN'),
#  ('is', 'VBZ'),
#  ('a', 'DT'),
#  ('beautiful', 'JJ'),
#  ('day', 'NN')]

# %%
blob.noun_phrases
# Out:
# WordList(['beautiful day'])

# %%
blob.sentiment
# Out:
# Sentiment(polarity=0.85, subjectivity=1.0)

# %%
# %precision 3
# Out:
# '%.3f'

# %%
blob.sentiment.polarity
# Out:
# 0.850

# %%
blob.sentiment.subjectivity
# Out:
# 1.000

# %%
from textblob.sentiments import NaiveBayesAnalyzer
blob = TextBlob(text,analyzer=NaiveBayesAnalyzer())
blob
# Out:
# TextBlob("Today is a beautiful day.")

# %%
blob.sentiment
# Out:
# Sentiment(classification='pos', p_pos=0.8117563121751951, p_neg=0.18824368782480477)

# %%
from textblob import Word
index = Word("index")
index.pluralize()
# Out:
# 'indices'

# %%
cacti = Word('cacti')
cacti.singularize()
# Out:
# 'cactus'

# %%
animals = TextBlob("dog cat fish bird").words
animals.pluralize()
# Out:
# WordList(['dogs', 'cats', 'fish', 'birds'])

# %%
from pathlib import Path 
blob = TextBlob(Path("RomeoAndJuliet.txt").read_text())

# %%
word = Word("strawberries")
print(word.stem())
print(word.lemmatize())
# Out:
# strawberri
# strawberry
