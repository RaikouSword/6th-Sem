# %% [markdown]
# # Q1
# ### Write a recursive function power(base, exponent) that, when called, returns base^exponent. <br> Example: power(3,4) = 3×3×3×3. Both base and exponent are user-defined and assume that the exponent is an integer greater than or equal to 1.
